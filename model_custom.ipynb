# %% [markdown]
# <a href="https://colab.research.google.com/github/Silvasss/custom-model-gpt2/blob/main/model_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Passo

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install gpt-2-simple
# Out:
# ...
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.2-cp37-none-any.whl size=23621 sha256=f2c00319d378c9405f324af680567c1a31b3362c43f9aa44c586658fa85d4c94
#   Stored in directory: /root/.cache/pip/wheels/68/1d/15/c87a4302a6c7273ce1b4f282bec3c6877fb2f521535d87d30f
# Successfully built gpt-2-simple
# ...

# %%
import gpt_2_simple as gpt2
from datetime import datetime
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.download_gpt2(model_name='124M')
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 393Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 2.27Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 322Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:14, 34.9Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 257Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 2.97Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 2.91Mit/s]

# %%
from google.colab import files

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
tf.reset_default_graph()

# %%
sess = gpt2.start_tf_sess()

# %%
gpt2.finetune(sess, dataset="fly.txt", steps=12000, model_name="124M")
# Out:
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:36<00:00, 37.00s/it]
# Streaming output truncated to the last 5000 lines.
# TOMEL - O senhor conhece esse homem?
#
# HENRIQUE - Sim; eu se o vi!
#
# VASCONCELOS - No podia ser mesmo? (Baixo no acorde ento.)
#
# HENRIQUE - Sei que h de falar no seu nome!... E no sei a quem sabe! (Arua mea)
#
# VASCONCELOS - Todos esto mortos!
#
# HENRIQUE - Oh! Bela est ainda no que eu chora!
#
# VASCONCELOS - Para aqui!... O primeiro amor.
#
# HENRIQUE - Para qu? No lhe escapou.
#
# VASCONCELOS - Quem sabe, meu pai! Ela est ainda no seu nome e tenho
# nossa famlia pagar a minha memria!
#
# HENRIQUE - E o nome...
#
# VASCONCELOS - Esta que me parecendo s suas mos.
#
# HENRIQUE - Ento entende isso?
#
# VASCONCELOS - Porque o senhor no teve como est ainda aqui.
#
# HENRIQUE - Meu Deus! Nhonh podes te amar.
#
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run1')

# %%
gpt2.generate(sess, run_name='run1', prefix="O que deveria ser considerado inaceitável?", length=200)
# Out:
# O que deveria ser considerado inaceitável?
#
# Saimos do bem e do mal dos dois colaboradores que sobreviveram
# ao Brasil.
#
# Alm do Tempo, vimos que ocorreram os preceitos das tropas do
# Interior. Nao se sabe mais sobre o sequestrador deles. Quanto mais
# sobreviveram, menos sobreviveram ao Oriente.
#
# O preceito  a nossa volta. O preceito  a nossa vontade. O nico
# preceito  o preceito. O preceito  a nossa existncia. O preceito  a
# nossa existncia.
#
# E, na verdade,  a nossa existncia sem saber o que pensamos. O
# preceito  a preceitura

# %%
gpt2.generate(sess, run_name='run1', length=200)
# Out:
# so esta agindo muito mais que o que esta fazendo.
#
# Esta  uma criatividade humana.
#
# Esse tipo de trabalho tem um nivelamento muito profundo de processos de producao e
# formas de trabalho. O processo de producao transforma novos produtos em
# mercadorias, cada um transforma em produto. As criaturas se tornam
# trabalhadores menores de 13 a 18 anos, enquanto as criaturas menores de 15 anos que
# trabalham, sem parar, sem se tornarem menores de 10 anos, sem aumentar a
# producao em escala colossal. A parte menor do produtor que trabalha se v ao seu
# produto, cada ve

# %%
# Out:
#   File "<ipython-input-27-f188d5ac1197>", line 1
#     git init
#            ^
# SyntaxError: invalid syntax
